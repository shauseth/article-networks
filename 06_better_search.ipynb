# %% [markdown]
# **Purpose:** Make search better.

# %%
import os
import pandas as pd
import numpy as np
import pubmed_parser as pp
from tqdm.notebook import tqdm

# %%
path_all = pp.list_xml_path('data/')

# %%
columns = ['full_title', 'abstract', 'journal', 'pmid', 'pmc', 'doi',
       'publisher_id', 'author_list', 'affiliation_list', 'publication_year',
       'publication_date', 'subjects', 'path_to_file']

data = pd.DataFrame(columns = columns)

# %%
path_some = path_all[:10000]

for path in tqdm(path_some):
    article = pp.parse_pubmed_xml(path, include_path = True)
    data = data.append(article, ignore_index = True)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=10000.0), HTML(value='')))

# %%
def get_authors(author_list):
    if author_list:
        author_arr = np.char.array(author_list).astype(str)[:, :-1]
        name_arr = author_arr[:, 1] + ' ' + author_arr[:, 0]
        _, idx = np.unique(name_arr, return_index = True)
        authors = ', '.join(name_arr[np.sort(idx)][:2]) + ', et al.'
        return authors
    else:
        return ''

def get_cover(article):
    title = article['full_title']
    authors = get_authors(article['author_list'])
    journal = article['journal']
    year = article['publication_year']
    info = authors + ' ' + journal + ' ' + year
    return title, info

def get_url(article):
    url_prefix = 'https://www.ncbi.nlm.nih.gov/pmc/articles/PMC'
    url = url_prefix + article['pmc'] + '/'
    return url

# %%
def search_title(query):
    searched = data[data['full_title'].str.contains(query, case = False)]
    return searched

# %%
query = 'alzheimer\'s'

searched = search_title(query)

# %%
for i, article in searched.iterrows():
    title, info = get_cover(article)
    url = get_url(article)
    print(title)
    print(info)
    print(url)
    print('')
# Out:
# Haplotype-based association analysis of the MAPT locus in Late Onset Alzheimer's disease
# Odity Mukherjee, John SK Kauwe, et al. BMC Genetics 2007
# https://www.ncbi.nlm.nih.gov/pmc/articles/PMC1800865/
#
# Defective mitochondrial respiration, altered dNTP pools and reduced AP endonuclease 1 activity in peripheral blood mononuclear cells of Alzheimer's disease patients
# Scott Maynard, Anne-Mette Hejl, et al. Aging (Albany NY) 2015
# https://www.ncbi.nlm.nih.gov/pmc/articles/PMC4637207/
#
# Beneficial effects of novel antagonists of GHRH in different models of Alzheimer's disease
# Miklos Jaszberenyi, Ferenc G. Rick, et al. Aging (Albany NY) 2012
# https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3560443/
#
# Phosphorylation of amyloid beta (Aβ) peptides – A trigger for formation of toxic aggregates in Alzheimer's disease
# Sathish Kumar, Jochen Walter, et al. Aging (Albany NY) 2011
# https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3184981/
#
# STARD1 and NPC1 expression as pathological markers associated with astrogliosis in post-mortem brains from patients with Alzheimer's disease and Down syndrome
# Fabian Arenas, Fernanda Castro, et al. Aging (Albany NY) 2020
# https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6977657/
#
# The heterogeneity within Alzheimer's disease
# Daniel Ferreira, Lars-Olof Wahlund, et al. Aging (Albany NY) 2018
# https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6286835/
#
# Alzheimer's Disease, time to turn the tide
# Stefano L. Sensi, et al. Aging (Albany NY) 2018
# https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6224239/
#
# Inhalational Alzheimer's disease: an unrecognized—and treatable—epidemic
# Dale E. Bredesen, et al. Aging (Albany NY) 2016
# https://www.ncbi.nlm.nih.gov/pmc/articles/PMC4789584/
#
# Common mechanisms involved in Alzheimer's disease and type 2 diabetes: a key role of chronic bacterial infection and inflammation
# Judith Miklossy, Patrick L. McGeer, et al. Aging (Albany NY) 2016
# https://www.ncbi.nlm.nih.gov/pmc/articles/PMC4925815/
#
# Repression of Alzheimer's beta-Secretase
# Francesca-Fang Liao, Ruishan Wang, et al. Aging (Albany NY) 2013
# https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3868720/
#
# Reversal of cognitive decline in Alzheimer's disease
# Dale E. Bredesen, Edwin C. Amos, et al. Aging (Albany NY) 2016
# https://www.ncbi.nlm.nih.gov/pmc/articles/PMC4931830/
#
# Targeting therapy for homocysteic acid in the blood represents a potential recovery treatment for cognition in Alzheimer's disease patients
# Tohru Hasegawa, Wataru Ukai, et al. Aging (Albany NY) 2016
# https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5076440/
#
# APOE ε4 specific imbalance of arachidonic acid and docosahexaenoic acid in serum phospholipids identifies individuals with preclinical Mild Cognitive Impairment/Alzheimer's Disease
# Laila Abdullah, James E Evans, et al. Aging (Albany NY) 2017
# https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5391242/
#
# Transgenic autoinhibition of p21-activated kinase exacerbates synaptic impairments and fronto-dependent behavioral deficits in an animal model of Alzheimer's disease
# Cyril Bories, Dany Arsenault, et al. Aging (Albany NY) 2017
# https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5472739/
#
# Primate-specific miR-603 is implicated in the risk and pathogenesis of Alzheimer's disease
# Chi Zhang, Jie Lu, et al. Aging (Albany NY) 2016
# https://www.ncbi.nlm.nih.gov/pmc/articles/PMC4789582/
#
# Interpretation and applicability of microRNA data to the context of                         Alzheimer's and age-related diseases
#  Aging (Albany NY) 2010
# https://www.ncbi.nlm.nih.gov/pmc/articles/PMC2871245/
#
# Down syndrome and Alzheimer's disease: common molecular traits beyond the amyloid precursor protein
# Wileidy Gomez, Rodrigo Morales, et al. Aging (Albany NY) 2020
# https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6977673/
#
# Inhibition of Polo-like kinase 1 reduces beta-amyloid-induced neuronal cell death in Alzheimer's disease
# Bing Song, Korbin Davis, et al. Aging (Albany NY) 2011
# https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3227450/
#
# Identification of molecular correlations of RBM8A with autophagy in Alzheimer's disease
# Donghua Zou, Rongjie Li, et al. Aging (Albany NY) 2019
# https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6932873/
#
# Unfolded p53 in the pathogenesis of Alzheimer's disease: is HIPK2 the link?
# Serena Stanga, Cristina Lanni, et al. Aging (Albany NY) 2010
# https://www.ncbi.nlm.nih.gov/pmc/articles/PMC2984604/
#
# Mitochondrial superoxide: a key player in Alzheimer's disease
# Cynthia A. Massaad, Robia G. Pautler, et al. Aging (Albany NY) 2009
# https://www.ncbi.nlm.nih.gov/pmc/articles/PMC2815734/
#
# Geniposide-mediated protection against amyloid deposition and behavioral impairment correlates with downregulation of mTOR signaling and enhanced autophagy in a mouse model of Alzheimer's disease
# Zhihua Zhang, Xiaojian Wang, et al. Aging (Albany NY) 2019
# https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6366989/
#
# Transcriptional evidence for the "Reverse Warburg Effect" in human                         breast cancer tumor stroma and metastasis: Similarities with oxidative stress,                         inflammation, Alzheimer's disease, and "Neuron-Glia Metabolic Coupling"
# Stephanos Pavlides, Aristotelis Tsirigos, et al. Aging (Albany NY) 2010
# https://www.ncbi.nlm.nih.gov/pmc/articles/PMC2881509/
#
# Metabolic profiling distinguishes three subtypes of Alzheimer's disease
# Dale E. Bredesen, et al. Aging (Albany NY) 2015
# https://www.ncbi.nlm.nih.gov/pmc/articles/PMC4586104/
#
# An antioxidant specifically targeting mitochondria delays progression of Alzheimer's disease-like pathology
# Natalia A. Stefanova, Natalia A. Muraleva, et al. Aging (Albany NY) 2016
# https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5191865/
#
# Ribonucleoprotein Therapy in Alzheimer's Disease?
#  Aging (Albany NY) 2014
# https://www.ncbi.nlm.nih.gov/pmc/articles/PMC4100804/
#
# Identifying circRNA-associated-ceRNA networks in the hippocampus of Aβ1-42-induced Alzheimer's disease-like rats using microarray analysis
# Zhe Wang, Panpan Xu, et al. Aging (Albany NY) 2018
# https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5940119/
#
# The neuronal cell cycle as a mechanism of pathogenesis in                         Alzheimer's disease
# Antonio Currais, Tibor Hortobágyi, et al. Aging 2009
# https://www.ncbi.nlm.nih.gov/pmc/articles/PMC2806021/
#
# RNA-Seq analysis of two brain regions vulnerable to Alzheimer's disease
# Xinkun Wang, et al. BMC Proceedings 2012
# https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3467687/
#
# Oral curcumin for Alzheimer's disease: tolerability and efficacy in a 24-week randomized, double blind, placebo-controlled study
# John M Ringman, Sally A Frautschy, et al. Alzheimer's Research & Therapy 2012
# https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3580400/
#
# Overlapping profiles of Aβ peptides in the Alzheimer's disease and pathological aging brains
# Brenda D Moore, Paramita Chakrabarty, et al. Alzheimer's Research & Therapy 2012
# https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3506932/
#
# Plasma lipoprotein-associated phospholipase A 2  activity in Alzheimer's disease, amnestic mild cognitive impairment, and cognitively healthy elderly subjects: a cross-sectional study
# Julie E Davidson, Andrew Lockhart, et al. Alzheimer's Research & Therapy 2012
# https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3580460/
#
# Pooled-DNA sequencing identifies novel causative variants in  PSEN1 ,  GRN  and  MAPT  in a clinical early-onset and familial Alzheimer's disease Ibero-American cohort
# Sheng Chih Jin, Pau Pastor, et al. Alzheimer's Research & Therapy 2012
# https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3506948/
#
# Exploring the potential of the platelet membrane proteome as a source of peripheral biomarkers for Alzheimer's disease
# Laura E Donovan, Eric B Dammer, et al. Alzheimer's Research & Therapy 2013
# https://www.ncbi.nlm.nih.gov/pmc/articles/PMC4054949/
#
# Amyloid precursor protein selective gamma-secretase inhibitors for treatment of Alzheimer's disease
# Guriqbal S Basi, Susanna Hemphill, et al. Alzheimer's Research & Therapy 2010
# https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3031881/
#
# The neurotrophic compound J147 reverses cognitive impairment in aged Alzheimer's disease mice
# Marguerite Prior, Richard Dargusch, et al. Alzheimer's Research & Therapy 2013
# https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3706879/
#
# Cerebrospinal fluid biomarkers for Alzheimer's and vascular disease vary by age, gender, and  APOE  genotype in cognitively normal adults
# Ge Li, Jane B. Shofer, et al. Alzheimer's Research & Therapy 2017
# https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5496132/
#
# Neuroprotective effects of D-Ala 2 GIP on Alzheimer's disease biomarkers in an APP/PS1 mouse model
# Emilie Faivre, Christian Hölscher, et al. Alzheimer's Research & Therapy 2013
# https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3706793/
#
# Predicting Alzheimer's disease development: a comparison of cognitive criteria and associated neuroimaging biomarkers
# Brandy L. Callahan, Joel Ramirez, et al. Alzheimer's Research & Therapy 2015
# https://www.ncbi.nlm.nih.gov/pmc/articles/PMC4634913/
#
# Metabolic correlates of reserve and resilience in MCI due to Alzheimer's Disease (AD)
# Matteo Bauckneht, Andrea Chincarini, et al. Alzheimer's Research & Therapy 2018
# https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5883593/
#
# CLU, CR1 and PICALM genes associate with Alzheimer's-related senile plaques
# Eloise H Kok, Teemu Luoto, et al. Alzheimer's Research & Therapy 2011
# https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3226274/
#
# A Quick Test of cognitive speed is sensitive in detecting early treatment response in Alzheimer's disease
# Sebastian Palmqvist, Lennart Minthon, et al. Alzheimer's Research & Therapy 2010
# https://www.ncbi.nlm.nih.gov/pmc/articles/PMC2983438/
#
# Mild versus moderate stages of Alzheimer's disease: three-year outcomes in a routine clinical setting of cholinesterase inhibitor therapy
# Carina Wattmo, Lennart Minthon, et al. Alzheimer's Research & Therapy 2016
# https://www.ncbi.nlm.nih.gov/pmc/articles/PMC4756534/
#
# Validation of the relevant outcome scale for Alzheimer's disease: a novel multidomain assessment for daily medical practice
# Vjera A Holthoff, Steven Ferris, et al. Alzheimer's Research & Therapy 2011
# https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3218804/
#
# Comprehensive behavioral characterization of an APP/PS-1 double knock-in mouse model of Alzheimer's disease
# Scott J Webster, Adam D Bachstetter, et al. Alzheimer's Research & Therapy 2013
# https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3706792/
#
# Predictors of long-term cognitive outcome in Alzheimer's disease
# Carina Wattmo, Åsa K Wallin, et al. Alzheimer's Research & Therapy 2011
# https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3226278/
#
# Analyzing the impact of 23 mg/day donepezil on language dysfunction in moderate to severe Alzheimer's disease
# Steven H Ferris, Frederick A Schmitt, et al. Alzheimer's Research & Therapy 2011
# https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3226311/
#
# Visual hallucinations in Alzheimer's disease do not seem to be associated with chronic hypoperfusion of to visual processing areas V2 and V3 but may be associated with reduced cholinergic input to these areas
# Lindsey Isla Sinclair, Amit Kumar, et al. Alzheimer's Research & Therapy 2019
# https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6740037/
#
# Effects of donepezil 23 mg on Severe Impairment Battery domains in patients with moderate to severe Alzheimer's disease: evaluating the impact of baseline severity
# Steven Ferris, Jeffrey Cummings, et al. Alzheimer's Research & Therapy 2013
# https://www.ncbi.nlm.nih.gov/pmc/articles/PMC4055003/
#
# Dose and plasma concentration of galantamine in Alzheimer's disease - clinical application
# Carina Wattmo, Erik Jedenius, et al. Alzheimer's Research & Therapy 2013
# https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3580330/
#
# Would you want to know? Public attitudes on early diagnostic testing for Alzheimer's disease
# Elizabeth M Wikler, Robert J Blendon, et al. Alzheimer's Research & Therapy 2013
# https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3978817/
#
# Masitinib as an adjunct therapy for mild-to-moderate Alzheimer's disease: a randomised, placebo-controlled phase 2 trial
# François Piette, Joël Belmin, et al. Alzheimer's Research & Therapy 2011
# https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3226277/
#
# Review of Alzheimer's disease scales: is there a need for a new multi-domain scale for therapy evaluation in medical practice?
# Philippe Robert, Steven Ferris, et al. Alzheimer's Research & Therapy 2010
# https://www.ncbi.nlm.nih.gov/pmc/articles/PMC2949590/
#
# Pro: Are we ready to translate Alzheimer's disease modifying therapies to people with Down syndrome?
# Michael S Rafii, et al. Alzheimer's Research & Therapy 2014
# https://www.ncbi.nlm.nih.gov/pmc/articles/PMC4255529/
#
# Role of ABCA7 loss-of-function variant in Alzheimer's disease: a replication study in European–Americans
# Jorge L. Del-Aguila, Maria Victoria Fernández, et al. Alzheimer's Research & Therapy 2015
# https://www.ncbi.nlm.nih.gov/pmc/articles/PMC4675010/
#
# Memantine in patients with Alzheimer's disease receiving donepezil: new analyses of efficacy and safety for combination therapy
# Alireza Atri, José L Molinuevo, et al. Alzheimer's Research & Therapy 2013
# https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3580327/
#
# For debate: substituting placebo controls in long-term Alzheimer's prevention trials
# René Spiegel, Manfred Berres, et al. Alzheimer's Research & Therapy 2011
# https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3226271/
#
# Dystrophic neurites express C9orf72 in Alzheimer's disease brains
# Jun-ichi Satoh, Hiroko Tabunoki, et al. Alzheimer's Research & Therapy 2012
# https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3506947/
#
# Simulations of symptomatic treatments for Alzheimer's disease: computational analysis of pathology and mechanisms of drug action
# Patrick D Roberts, Athan Spiros, et al. Alzheimer's Research & Therapy 2012
# https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3580459/
#
# Modeling the heterogeneity in risk of progression to Alzheimer's disease across cognitive profiles in mild cognitive impairment
# Curtis Tatsuoka, Huiyun Tseng, et al. Alzheimer's Research & Therapy 2013
# https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3707057/
#
# Alterations of matrix metalloproteinases in the healthy elderly with increased risk of prodromal Alzheimer's disease
# Erik Stomrud, Maria Björkqvist, et al. Alzheimer's Research & Therapy 2010
# https://www.ncbi.nlm.nih.gov/pmc/articles/PMC2919700/
#
# A double-blind placebo-controlled cross-over clinical trial of DONepezil In Posterior cortical atrophy due to underlying Alzheimer's Disease: DONIPAD study
# Basil H. Ridha, Sebastian Crutch, et al. Alzheimer's Research & Therapy 2018
# https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5930935/
#
# Predicting progression of Alzheimer's disease
# Rachelle S Doody, Valory Pavlik, et al. Alzheimer's Research & Therapy 2010
# https://www.ncbi.nlm.nih.gov/pmc/articles/PMC2874261/
